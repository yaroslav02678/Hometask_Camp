# %% [markdown]
# ### Моє робоче середовище
# #### Герасимчук Ярослав
# #### Версія Python
# <img src="image/python_version.jpg">

# %% [markdown]
# ### Версія Conda
# <img src="image/conda_version.jpg">

# %% [markdown]
# ### Версія jupyther notebook
# <img src="image/jupyter_notebook_version.jpg">

# %% [markdown]
# ### Версія pip
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Версія jupyter lab
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Версія pandas
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Версії бібліотек
# ![image.png](attachment:image.png)

# %% [markdown]
# Використовую jupyter notebook та Anaconda.->Enviroment
